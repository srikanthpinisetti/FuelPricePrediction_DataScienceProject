# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive/DataScienceProject')
import pandas as pd
import numpy as np
from Packages.DP import DP
from Packages.QC import QC

# %%
raw = pd.read_csv('Raw data/data_raw.csv')
raw.head()
# Out:
#     Date    Cushing, OK WTI Crude oil Spot Price FOB (Dollars per Barrel)   \
# 0  Jun-86                                              13.43
# 1  Jul-86                                              11.59
# 2  Aug-86                                              15.10
# 3  Sep-86                                              14.87
# 4  Oct-86                                              14.90
#
#     Europe Brent Spot Price FOB (Dollars per Barrel)   \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#     U.S. Field Production of Crude Oil (Thousand Barrels)   \
# 0                                           258700.0
# 1                                           268448.0
# 2                                           259580.0
# ...

# %% [markdown]
# #Process

# %%
raw_stats = QC(raw,save_to='Results/Stats',filename='raw_stats').qc()
raw_stats
# Out:
#                                                      Example     Type  N_rows  \
#  Alaska Field Production of Crude Oil (Thousand...   35037.0  float64     435
#  Cushing, OK WTI Crude oil Spot Price FOB (Doll...     94.62  float64     435
#  Date                                                 Jun-20   object     435
#  Europe Brent Spot Price FOB (Dollars per Barrel)      59.71  float64     435
#  New York Harbor Conventional Gasoline Regular ...      2.39  float64     435
#  U.S. Field Production of Crude Oil (Thousand B...  169703.0  float64     435
#  U.S. Imports of Crude Oil (Thousand Barrels)       225255.0  float64     435
#  U.S. Percent of Crude Oil Stocks Held in SPR (...      71.5  float64     435
#  U.S. Percent of Total Petroleum Stocks Held in...      34.6  float64     435
#
#                                                     Missing values  \
#  Alaska Field Production of Crude Oil (Thousand...               0
# ...

# %%
processed = DP(raw, target=' New York Harbor Conventional Gasoline Regular Spot Price FOB (Dollars per Gallon) ',
               fillna_median=[' Europe Brent Spot Price FOB (Dollars per Barrel) ',
       ' U.S. Field Production of Crude Oil (Thousand Barrels) ',
       ' Alaska Field Production of Crude Oil (Thousand Barrels) ',
       ' U.S. Imports of Crude Oil (Thousand Barrels) ',
       ' U.S. Percent of Crude Oil Stocks Held in SPR (Percent) ',
       ' U.S. Percent of Total Petroleum Stocks Held in SPR (Percent) '],save_to='Clean data',filename='data_cleaned').process()
processed.head()
# Out:
# Target column is  New York Harbor Conventional Gasoline Regular Spot Price FOB (Dollars per Gallon)
#     Date    Cushing, OK WTI Crude oil Spot Price FOB (Dollars per Barrel)   \
# 0  Jun-86                                              13.43
# 1  Jul-86                                              11.59
# 2  Aug-86                                              15.10
# 3  Sep-86                                              14.87
# 4  Oct-86                                              14.90
#
#     Europe Brent Spot Price FOB (Dollars per Barrel)   \
# 0                                              38.11
# 1                                              38.11
# 2                                              38.11
# 3                                              38.11
# 4                                              38.11
#
#     U.S. Field Production of Crude Oil (Thousand Barrels)   \
# 0                                           258700.0
# ...

# %%
QC(processed,save_to='Results/Stats',filename='cleaned_stats').qc()
# Out:
#                                                      Example     Type  N_rows  \
#  Alaska Field Production of Crude Oil (Thousand...   13259.0  float64     435
#  Cushing, OK WTI Crude oil Spot Price FOB (Doll...     20.42  float64     435
#  Date                                                 Dec-01   object     435
#  Europe Brent Spot Price FOB (Dollars per Barrel)      53.31  float64     435
#  New York Harbor Conventional Gasoline Regular ...     0.627  float64     435
#  U.S. Field Production of Crude Oil (Thousand B...  248356.0  float64     435
#  U.S. Imports of Crude Oil (Thousand Barrels)       158100.0  float64     435
#  U.S. Percent of Crude Oil Stocks Held in SPR (...      63.1  float64     435
#  U.S. Percent of Total Petroleum Stocks Held in...      34.1  float64     435
#
#                                                     Missing values  \
#  Alaska Field Production of Crude Oil (Thousand...               0
# ...
